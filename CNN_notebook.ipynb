# %% [markdown]
# # Aula 15
#
# # Exemplo de visão estéreo
#
# ### Eduardo Lobo Lustosa Cabral

# %% [markdown]
# ## 1. Objetivos
#
# Apresentar a solução de um problema de visão estéreo usando uma RNA.

# %% [markdown]
# ### Importação das principais bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from glob import glob
import os
from calibrator import calibrate
import cv2

print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# ## 2. Conjunto de dados
#
# O conjunto de dados que vamos utilizar nessa aula é o "New Tsukuba Stereo Dataset" (https://home.cvlab.cs.tsukuba.ac.jp/dataset).
#
# Esse conjunto de dados é composto por quase 1.800 pares de imagens com dimensão 480x480 pixels. Portanto, temos que carregá-lo em versão compactada para depois descompactar.
#
#
# ### 2.1 Carregar conjunto de dados
#
# A célula abaixo instala o `gdown` para carregar um arquivo que está no Google Drive e depois carrega esse arquivo no diretório local "/tmp" do Colab.

# %%
import os
import zipfile

local_zip = '/content/images_colab.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/content')
zip_ref.close()

ret, mtx, dist, rvecs, tvecs = calibrate('calib/right_cal/*.png')
h,  w = right_imagem.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),1,(w,h))

# %% [markdown]
# Após a descompressão do arquivo de dados é criado o diretório "/tmp/TsukubaStereo" com dois subdiretórios: "images" e "disparityl", onde estão as imagens e os mapas de disparidades.
#
# O diretório "images" é subdividido nos diretórios "left" e "right" onde ficam as imagens das câmeras esquerda e direita respectivamente. O diretório "disparity" é subdividido nso diretórios "left" e "right" onde ficam os mapas de diretórios referentes às imagens da esquerda e da direita respectivamente. Nesse exemplo vamos usar o mapa de disparidade referente è câmera da esquerda.
#
# Na célula abaixo são criadas as listas dos arquivos contidos nesses diretórios.

# %%
# Define diretório onde se encontram as imagens
left_image_path = '/content/images_colab/leftinho'
right_image_path = '/content/images_colab/rightinho'


# Escolhe tipos de arquivos desejados
glob_left_imgs = os.path.join(left_image_path, '*.png')
glob_right_imgs = os.path.join(right_image_path, '*.png')


# Cria lista dos nomes dos arquivos
left_img_paths = glob(glob_left_imgs)
right_img_paths = glob(glob_right_imgs)


# Ordena lista dos arquivos
left_img_paths.sort()
right_img_paths.sort()

# Apresenta numero de imagens
print('Número de imagens da esquerda:', len(left_img_paths))
print('Número de imagens da direita:', len(right_img_paths))
print(' ')

# Imprime nomes e paths dos 5 primeiros arquivos das listas
print('Nomes dos 5 primeiros arquivos das listas:')
print(' ')
print(left_img_paths[:5])
print(' ')
print(right_img_paths[:5])
print(' ')
# Out:
# Número de imagens da esquerda: 500
# Número de imagens da direita: 500
#
# Nomes dos 5 primeiros arquivos das listas:
#
# ['/content/images_colab/leftinho/left_1661693702546096400.png', '/content/images_colab/leftinho/left_1661693703048086700.png', '/content/images_colab/leftinho/left_1661693703549215800.png', '/content/images_colab/leftinho/left_1661693704051095900.png', '/content/images_colab/leftinho/left_1661693704553087600.png']
#
# ['/content/images_colab/rightinho/right_1661693702546096400.png', '/content/images_colab/rightinho/right_1661693703048086700.png', '/content/images_colab/rightinho/right_1661693703549215800.png', '/content/images_colab/rightinho/right_1661693704051095900.png', '/content/images_colab/rightinho/right_1661693704553087600.png']

# %%
# Importa função para embaralhar os dados
from sklearn.utils import shuffle

left_img_paths, right_img_paths = shuffle(left_img_paths, right_img_paths)

# Imprime nomes e paths dos 5 primeiros arquivos das listas
print('Nomes dos 5 primeiros arquivos das listas:')
print(' ')
print(left_img_paths[:5])
print(' ')
print(right_img_paths[:5])
print(' ')
# Out:
# Nomes dos 5 primeiros arquivos das listas:
#
# ['/content/images_colab/leftinho/left_1661693945417900700.png', '/content/images_colab/leftinho/left_1661693893281947500.png', '/content/images_colab/leftinho/left_1661693877250956400.png', '/content/images_colab/leftinho/left_1661693747140055400.png', '/content/images_colab/leftinho/left_1661693776012104700.png']
#
# ['/content/images_colab/rightinho/right_1661693945417900700.png', '/content/images_colab/rightinho/right_1661693893281947500.png', '/content/images_colab/rightinho/right_1661693877250956400.png', '/content/images_colab/rightinho/right_1661693747140055400.png', '/content/images_colab/rightinho/right_1661693776012104700.png']

# %% [markdown]
# Para entender esse conjunto de dados vamos visualizar alguns pares de imagens e o mapa de disparidade.

# %%
# Importa função para ler imagem
from keras.preprocessing.image import load_img, img_to_array

# Seleção da imagem
index = 1

# Carrega algumas imagens
img_left = load_img(left_img_paths[index])
img_right = load_img(right_img_paths[index])

# convert to numpy array
img_left = img_to_array(img_left)
img_right = img_to_array(img_right)

# Elimina 4o canal
img_left = img_left[:,:,:3]
img_right = img_right[:,:,:3]

# Mostra imagens 
f, pos = plt.subplots(1, 2, figsize=(16, 16))
pos[0].imshow(img_left/255)
pos[1].imshow(img_right/255)

# Mostra dimensões 
print('Dimensões das imagens:', img_left.shape)
print('Valor máximo dos pixels das imagens:', np.max(img_left))

heigth_orig = img_left[0]
weigth_orig = img_left[1]
# Out:
# Dimensões das imagens: (360, 640, 3)
# Valor máximo dos pixels das imagens: 255.0

# %% [markdown]
# ### 2.2 Divisão dos dados em conjuntos de treinamento e validação
#
# Como essa imagens foram obtidas em sequência, como se fosse um vídeo, e não vamos usar a informação temporal então temos que embaralhar os exemplos, antes de usá-los e antes de dividir os dados nos conjunto de treinamento e validação.

# %%
# Conjunto de dados de treinamento
train_left_img_paths = left_img_paths[:400]
train_right_img_paths = right_img_paths[:400]

# Conjunto de dados de validação
val_left_img_paths = left_img_paths[400:]
val_right_img_paths = right_img_paths[400:]

# Numero de exemplos
print(len(train_left_img_paths), len(train_right_img_paths))
print(len(val_left_img_paths), len(val_right_img_paths))
# Out:
# 400 400
# 100 100

# %% [markdown]
# ## 3. Gerador de dados
#
# A dimensão das imagens de entrada e o mapa de disparidade são 480x640x3 e o conjunto de dados de treinamento possui 1.500 exemplos e o de validação 300 exemplos. Assim, não é possível carregar todas essas em tensores, portanto, temos que usar geradores de dados para carregar os lote de exemplos de treinamento e de validação um de cada vez.
#
# Na célula abaixo é criado um gerador que carrega as imagens dos diretórios onde se encontram e realiza as seguintes operações para criar os exemplos de treinamento e de validação:
#
# 1. Carrega as imagens da esquerda, da direita e o mapa de disparidade
# 2. Transforma as imagens em tensores
# 3. Redimensiona as imagens e o mapa de disparidade (essa imagens são muito grandes para o hardware disponível)
# 4. Normaliza as imagem de entrada para que os valores dos seus pixels sejam números reais entre 0 e 1

# %%
from keras.preprocessing.image import load_img, img_to_array

# Cria gerador para ser usado com o Keras
def batch_generator(left_img_paths, right_img_paths, img_size, m_exemplos, batchsize):
    # Inicializa loop infinito que termina no final do treinamento
    while True:
        
        # Loop para selecionar imagens de cada lote
        for start in range(0, m_exemplos, batchsize):
           
            # Inicializa lista de imagens com máscara e sem máscara
            batch_left_img, batch_right_img, batch_out_img = [], [], []
        
            end = min(start + batchsize, m_exemplos)
            for i in range(start, end):
                # Carrega images e o mapa de disparidade
                left_imagem = load_img(left_img_paths[i])
                right_imagem = load_img(right_img_paths[i])
                
                # Converet para tensor 
                left_imagem = img_to_array(left_imagem)
                right_imagem = img_to_array(right_imagem)

                # Elimina 4o canal
                left_imagem = left_imagem[:,:,:3]
                right_imagem = right_imagem[:,:,:3]
                
                # Redimensiona imagens e normaliza
                left_imagem = tf.image.resize(left_imagem, img_size)/255.
                right_imagem = tf.image.resize(right_imagem, img_size)/255.

                dst = cv2.undistort(right_imagem, mtx, dist, None, newcameramtx)
                # crop the image
                x,y,w,h = roi
                right_imagem = dst[y:y+h, x:x+w]
                ret, mtx, dist, rvecs, tvecs = calibrate('calib/left_cal/*.png')
                h,  w = left_imagem.shape[:2]
                newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),1,(w,h))
                dst = cv2.undistort(right_imagem, mtx, dist, None, newcameramtx)
                # crop the image
                x,y,w,h = roi
                right_imagem = dst[y:y+h, x:x+w]

                # Adiciona imagem original e segmentada aos lotes
                batch_left_img.append(left_imagem)
                batch_right_img.append(right_imagem)
                batch_out_img.append(right_imagem)
            
            yield [np.stack(batch_left_img, axis=0), np.stack(batch_right_img, axis=0)], [np.stack(batch_out_img, axis=0)]
            #Não tenho certeza se deixa o [] na saída

# %% [markdown]
# As duas células abaixo testam o gerador de dados nos exemplos de treinamento e de validação.

# %%
# Número de exemplos
m_train = len(train_left_img_paths)
m_val = len(val_left_img_paths)

# Define tamanho do lote
batch_size = 16

# Dimensão desejada para as imagens
img_size = (640, 360)


# Instancia o gerador de dados de treinamento
train_datagen = batch_generator(train_left_img_paths, train_right_img_paths, img_size, m_train, batchsize=batch_size)

# Usa o gerador uma vez
[left_img_batch, right_img_batch], [out_img_batch] = next(train_datagen)

# Apresenta dimensão dos tensores de entrada de saída
print('Dimensão dos tensores de imagens =', left_img_batch.shape, right_img_batch.shape, out_img_batch.shape)

# Mostra uma imagem dos lotes gerados
index = 0
print('Nomes dos arquivos:')
print(train_left_img_paths[index])
print(train_right_img_paths[index])
f, pos = plt.subplots(1, 3, figsize=(24, 16))
pos[0].imshow(left_img_batch[index])
pos[1].imshow(right_img_batch[index])
pos[2].imshow(out_img_batch[index])
plt.show()
# Out:
# Dimensão dos tensores de imagens = (16, 240, 320, 3) (16, 240, 320, 3) (16, 240, 320, 3)
# Nomes dos arquivos:
# /content/images_colab/leftinho/left_1661693945417900700.png
# /content/images_colab/rightinho/right_1661693945417900700.png

# %%
# Instancia o gerador de dados de validação
val_datagen = batch_generator(val_left_img_paths, val_right_img_paths, img_size, m_val, batchsize=batch_size)

# Usa o gerador uma veze
[left_img_batch, right_img_batch], [out_img_batch] = next(val_datagen)

# Apresenta dimensão dos tensores de entrada de saída
print('Dimensão dos tensores de imagens =', left_img_batch.shape, right_img_batch.shape, out_img_batch.shape)

# Mostra uma imagem dos lotes gerados
index = 1
print('Nomes das imagens:')
print(val_left_img_paths[index])
print(val_right_img_paths[index])
f, pos = plt.subplots(1, 3, figsize=(24, 16))
pos[0].imshow(left_img_batch[index])
pos[1].imshow(right_img_batch[index])
pos[2].imshow(out_img_batch[index])
plt.show()
# Out:
# Dimensão dos tensores de imagens = (16, 240, 320, 3) (16, 240, 320, 3) (16, 240, 320, 3)
# Nomes das imagens:
# /content/images_colab/leftinho/left_1661693729105074300.png
# /content/images_colab/rightinho/right_1661693729105074300.png

# %%
# Calcula números de lotes por época
train_steps = len(train_left_img_paths) // batch_size
val_steps = len(val_left_img_paths) // batch_size

print('Passos de treinamento:', train_steps)
print('Passos de validação:', val_steps)
# Out:
# Passos de treinamento: 25
# Passos de validação: 6

# %% [markdown]
# ## 4. Reconstrução

# %%
# Mostra uma imagem dos lotes gerados
index = 1
imgL = left_img_batch[index]
imgR = right_img_batch[index]

f, pos = plt.subplots(1, 2, figsize=(16, 16))
pos[0].imshow(imgL)
pos[1].imshow(imgR)
plt.show()

# %%
print(imgL.shape, imgR.shape)
# Out:
# (240, 320, 3) (240, 320, 3)

# %% [markdown]
# ### Camada de reconstrução

# %%
# Classe para reconstrutor
class Reconstructor(tf.keras.layers.Layer):
    def __init__(self, height=40, width=40, num_channels=3, name="rec_img"):
        super(Reconstructor, self).__init__(name=name)
        self.height = height
        self.width = width
        self.num_channels = num_channels

    def compute_output_shape(self, input_shape):
        return [None, self.height, self.width, 1]

    def get_config(self):
        return {
            'height': self.height,
            'width': self.width,
        }
    
    def build(self, input_shape):
        print("Building Reconstruction Layer with input shape:", input_shape)

    def repeat(self, x, n_repeats):
        #with tf.variable_scope('_repeat'):
        rep = tf.tile(tf.expand_dims(x, 1), [1, n_repeats])
        return tf.reshape(rep, [-1])

    def interpolate(self, im, x, y, _num_batch):
        _height_f = tf.cast(self.height, tf.float32)
        _width_f  = tf.cast(self.width,  tf.float32)        

        # handle both texture border types
        _edge_size = 1
        im = tf.pad(im, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT')
        x = x + _edge_size
        y = y + _edge_size

        x = tf.clip_by_value(x, 0.0,  _width_f - 1 + 2 * _edge_size)

        x0_f = tf.floor(x)
        y0_f = tf.floor(y)
        x1_f = x0_f + 1

        x0 = tf.cast(x0_f, tf.int32)
        y0 = tf.cast(y0_f, tf.int32)
        x1 = tf.cast(tf.minimum(x1_f,  _width_f - 1 + 2 * _edge_size), tf.int32)

        dim2 = (self.width + 2 * _edge_size)
        dim1 = (self.width + 2 * _edge_size) * (self.height + 2 * _edge_size)
        base = self.repeat(tf.range(_num_batch) * dim1, self.height * self.width)
        base_y0 = base + y0 * dim2
        idx_l = base_y0 + x0
        idx_r = base_y0 + x1

        im_flat = tf.reshape(im, tf.stack([-1, self.num_channels]))

        pix_l = tf.gather(im_flat, idx_l)
        pix_r = tf.gather(im_flat, idx_r)

        weight_l = tf.expand_dims(x1_f - x, 1)
        weight_r = tf.expand_dims(x - x0_f, 1)

        return weight_l * pix_l + weight_r * pix_r

    def transform(self, input_images, x_offset, _num_batch):
        _height_f = tf.cast(self.height, tf.float32)
        _width_f  = tf.cast(self.width,  tf.float32)
        
        x_t, y_t = tf.meshgrid(tf.linspace(0.0,   _width_f - 1.0,  self.width),
                               tf.linspace(0.0 , _height_f - 1.0 , self.height))

        x_t_flat = tf.reshape(x_t, (1, -1))
        y_t_flat = tf.reshape(y_t, (1, -1))

        x_t_flat = tf.tile(x_t_flat, tf.stack([_num_batch, 1]))
        y_t_flat = tf.tile(y_t_flat, tf.stack([_num_batch, 1]))

        x_t_flat = tf.reshape(x_t_flat, [-1])
        y_t_flat = tf.reshape(y_t_flat, [-1])

        x_t_flat = x_t_flat + tf.reshape(x_offset, [-1])

        input_transformed = self.interpolate(input_images, x_t_flat, y_t_flat, _num_batch)

        output = tf.reshape(input_transformed, tf.stack([_num_batch, self.height, self.width, self.num_channels]))
        
        return output

    def call(self, input_images,  x_offset):
        _num_batch    = tf.shape(input_images)[0]

        output = self.transform(input_images, x_offset, _num_batch)
        return output

# %%
def loss_erro_rec(y_true, y_pred):
    mask = tf.where(y_pred<1e-08,  0., 1.)
    erro = 255*tf.reduce_mean(tf.square(mask*(y_true - y_pred)))
    return erro  

rec = Reconstructor(height=left_img_batch.shape[1], width=left_img_batch.shape[2])

# %% [markdown]
# ### Rede de extração de catracterísticas

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# Número de filtros básico
nF = 32

# Rede convolucional de extração de características
def rna_carac(input_shape, nF):
    x0 = layers.Input(shape=input_shape)
    
    # Calculo das características das imagens
    x1 = layers.Conv2D(nF, (5,5), padding='same', activation=layers.LeakyReLU())(x0)
    x2 = layers.Conv2D(nF, (5,5), padding='same', use_bias=False)(x1)
    x2 = layers.BatchNormalization()(x2)
    x2 = layers.LeakyReLU()(x2)
    x2 = layers.MaxPool2D(2,2)(x2)

    x3 = layers.Conv2D(nF*2, (5,5), padding='same', activation=layers.LeakyReLU())(x2)
    x4 = layers.Conv2D(nF*2, (5,5), padding='same', use_bias=False)(x3)
    x4 = layers.BatchNormalization()(x4)
    x4 = layers.LeakyReLU()(x4)
    x4 = layers.MaxPool2D(2,2)(x4)

    x5 = layers.Conv2D(nF*4, (5,5), padding='same', activation=layers.LeakyReLU())(x4)
    x6 = layers.Conv2D(nF*4, (5,5), padding='same', use_bias=False)(x5)
    x6 = layers.BatchNormalization()(x6)
    x6 = layers.LeakyReLU()(x6) 
    x6 = layers.MaxPool2D(2,2)(x6)  

    x7 = layers.Conv2D(nF*4, (5,5), padding='same', activation=layers.LeakyReLU())(x6)
    x8 = layers.Conv2D(nF*4, (5,5), padding='same', use_bias=False)(x7)
    x8 = layers.BatchNormalization()(x8)
    x8 = layers.LeakyReLU()(x8)  


    # Cria modelo
    rna_carac = models.Model(x0, x8)
    
    return rna_carac

input_shape = (640, 360, 3)
rnaCV = rna_carac(input_shape, nF)

rnaCV.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 320, 3)]     0
#
#  conv2d (Conv2D)             (None, 240, 320, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 240, 320, 32)      25600
#
#  batch_normalization (BatchN  (None, 240, 320, 32)     128
#  ormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 240, 320, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 120, 160, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 120, 160, 64)      51264
#
#  conv2d_3 (Conv2D)           (None, 120, 160, 64)      102400
#
#  batch_normalization_1 (Batc  (None, 120, 160, 64)     256
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 120, 160, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 60, 80, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 60, 80, 128)       204928
#
#  conv2d_5 (Conv2D)           (None, 60, 80, 128)       409600
#
#  batch_normalization_2 (Batc  (None, 60, 80, 128)      512
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 60, 80, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 40, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 30, 40, 128)       409728
#
#  conv2d_7 (Conv2D)           (None, 30, 40, 128)       409600
#
#  batch_normalization_3 (Batc  (None, 30, 40, 128)      512
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 30, 40, 128)       0
#
# =================================================================
# Total params: 1,616,960
# Trainable params: 1,616,256
# Non-trainable params: 704
# _________________________________________________________________

# %%
img_carac = rnaCV(left_img_batch)
print(img_carac.shape)
# Out:
# (16, 30, 40, 128)

# %% [markdown]
# ## Rede completa

# %%
#### Rede de calculo da profundidade ####
input_shape = (img_size[0], img_size[1], 3)

# Define entradas
input_left = tf.keras.layers.Input(shape=input_shape)
input_right = tf.keras.layers.Input(shape=input_shape)

# Extrai características
xL = rnaCV(input_left)
xR = rnaCV(input_right)

# Cocatena com características
ac = layers.Concatenate(axis=-1)([xL, xR])

# Aplica convolução
x2 = layers.Conv2DTranspose(64, (3,3), padding='same', activation='relu', strides=(2,2))(ac)
x2 = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x2)

x3 = layers.Conv2DTranspose(32, (3,3), padding='same', activation='relu', strides=(2,2))(x2)
x3 = layers.Conv2D(32, (3,3), padding='same', activation='relu')(x3)

# Calcula da disparidade
x4 = layers.Conv2DTranspose(16, (3,3), padding='same', activation='relu', strides=(2,2))(x3)
x4 = layers.Conv2D(16, (3,3), padding='same', activation='relu')(x4)

x5 = layers.Conv2D(1, (1,1), padding='same', activation='relu')(x4)

disp_layer = layers.Lambda(lambda x: tf.squeeze(x), name='disp')
disp = disp_layer(x5)

# Imagem da direita reconstruída usando a imagem esquerda e a disparidade
img_rec = rec(input_left, disp)

# Create the Keras model.
rna_stereo = keras.Model(inputs=[input_left, input_right], outputs=[img_rec])                   
             
# Sumário da rede             
rna_stereo.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 240, 320, 3  0           []
#                                 )]
#
#  input_5 (InputLayer)           [(None, 240, 320, 3  0           []
#                                 )]
#
#  model (Functional)             (None, 30, 40, 128)  1616960     ['input_4[0][0]',
#                                                                   'input_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 30, 40, 256)  0           ['model[2][0]',
#                                                                   'model[3][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 60, 80, 64)  147520      ['concatenate_1[0][0]']
#  spose)
#
#  conv2d_12 (Conv2D)             (None, 60, 80, 64)   36928       ['conv2d_transpose_3[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 120, 160, 32  18464      ['conv2d_12[0][0]']
#  spose)                         )
#
#  conv2d_13 (Conv2D)             (None, 120, 160, 32  9248        ['conv2d_transpose_4[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 240, 320, 16  4624       ['conv2d_13[0][0]']
#  spose)                         )
#
#  conv2d_14 (Conv2D)             (None, 240, 320, 16  2320        ['conv2d_transpose_5[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 240, 320, 1)  17          ['conv2d_14[0][0]']
#
#  disp (Lambda)                  None                 0           ['conv2d_15[0][0]']
#
#  rec_img (Reconstructor)        (None, 240, 320, 3)  0           ['input_4[0][0]',
#                                                                   'disp[0][0]']
#
# ==================================================================================================
# Total params: 1,836,081
# Trainable params: 1,835,377
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
# Gera um esquema gráfico da rede
from tensorflow.keras.utils import plot_model
plot_model(rna_stereo, show_shapes=True, to_file='rna_stereo.png')

# %%
img_rec = rna_stereo([left_img_batch, right_img_batch])   
print(img_rec.shape, disp.shape)
# Out:
# (16, 240, 320, 3) <unknown>

# %% [markdown]
# ### 4.2 Compilação e treinamento
#
# A compilação da rede é feita usando os seguintes parâmetros:
#
# 1. Método de otimização: Adam com taxa de aprendizado de 0.001
# 2. Função de custo: erro quadrático médio (mse)
# 3. Métrica: erro absoluto médio (mae)

# %%
# Importa classe dos otimizadores
from tensorflow.keras import optimizers

# Define otimizador Adam
adam = optimizers.Adam(learning_rate=0.001, decay=1e-03)

# Compilação do autoencoder
rna_stereo.compile(optimizer=adam, 
                   loss={
                         'rec_img': loss_erro_rec},
                   metrics={
                         'rec_img': 'mae'})

# %% [markdown]
# O treinamento da rede é realizado usando 100 épocas.
#
# Como o treinamento é demorado, então, é conveniente utilizar um `callback` para salvar os parâmetros da rede durante o processo de treinamento.

# %%
# Importa callback para salvar modelo durante treinamento
from tensorflow.keras.callbacks import ModelCheckpoint

# Define o callback para salvar os parâmetros
checkpointer = ModelCheckpoint('rna_stereo_CVN_REC_weigths', verbose=1, save_best_only=True, save_weights_only=True)

# Treinamento da rede
results = rna_stereo.fit(
          batch_generator(train_left_img_paths, train_right_img_paths, img_size, m_train, batchsize=batch_size),
          steps_per_epoch=train_steps,
          epochs=100,
          validation_data=batch_generator(val_left_img_paths, val_right_img_paths, img_size, m_val, batchsize=batch_size),
          validation_steps=val_steps,
          callbacks=[checkpointer],
          verbose=1)
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 5.3170 - mae: 0.0898
# Epoch 1: val_loss improved from inf to 5.12045, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 24s 752ms/step - loss: 5.3170 - mae: 0.0898 - val_loss: 5.1204 - val_mae: 0.0893
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 5.1911 - mae: 0.0888
# Epoch 2: val_loss improved from 5.12045 to 4.99114, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 18s 746ms/step - loss: 5.1911 - mae: 0.0888 - val_loss: 4.9911 - val_mae: 0.0883
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 5.0734 - mae: 0.0879
# Epoch 3: val_loss improved from 4.99114 to 4.93822, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 18s 748ms/step - loss: 5.0734 - mae: 0.0879 - val_loss: 4.9382 - val_mae: 0.0877
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 4.9329 - mae: 0.0867
# Epoch 4: val_loss improved from 4.93822 to 4.73298, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 18s 747ms/step - loss: 4.9329 - mae: 0.0867 - val_loss: 4.7330 - val_mae: 0.0861
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 4.6520 - mae: 0.0844
# Epoch 5: val_loss improved from 4.73298 to 4.51500, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 761ms/step - loss: 4.6520 - mae: 0.0844 - val_loss: 4.5150 - val_mae: 0.0843
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 4.4035 - mae: 0.0822
# Epoch 6: val_loss improved from 4.51500 to 4.40271, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 760ms/step - loss: 4.4035 - mae: 0.0822 - val_loss: 4.4027 - val_mae: 0.0833
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 4.2219 - mae: 0.0805
# Epoch 7: val_loss improved from 4.40271 to 4.10245, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 757ms/step - loss: 4.2219 - mae: 0.0805 - val_loss: 4.1024 - val_mae: 0.0803
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 4.0912 - mae: 0.0792
# Epoch 8: val_loss improved from 4.10245 to 3.99777, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 764ms/step - loss: 4.0912 - mae: 0.0792 - val_loss: 3.9978 - val_mae: 0.0791
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 3.9742 - mae: 0.0781
# Epoch 9: val_loss did not improve from 3.99777
# 25/25 [==============================] - 19s 761ms/step - loss: 3.9742 - mae: 0.0781 - val_loss: 4.0714 - val_mae: 0.0799
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 3.8977 - mae: 0.0774
# Epoch 10: val_loss improved from 3.99777 to 3.91132, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 771ms/step - loss: 3.8977 - mae: 0.0774 - val_loss: 3.9113 - val_mae: 0.0783
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 3.8244 - mae: 0.0766
# Epoch 11: val_loss improved from 3.91132 to 3.85288, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 769ms/step - loss: 3.8244 - mae: 0.0766 - val_loss: 3.8529 - val_mae: 0.0777
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 3.8015 - mae: 0.0764
# Epoch 12: val_loss improved from 3.85288 to 3.84111, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 763ms/step - loss: 3.8015 - mae: 0.0764 - val_loss: 3.8411 - val_mae: 0.0774
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 3.7135 - mae: 0.0756
# Epoch 13: val_loss improved from 3.84111 to 3.62384, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 765ms/step - loss: 3.7135 - mae: 0.0756 - val_loss: 3.6238 - val_mae: 0.0753
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 3.6606 - mae: 0.0750
# Epoch 14: val_loss did not improve from 3.62384
# 25/25 [==============================] - 19s 757ms/step - loss: 3.6606 - mae: 0.0750 - val_loss: 3.8692 - val_mae: 0.0774
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 3.6283 - mae: 0.0747
# Epoch 15: val_loss did not improve from 3.62384
# 25/25 [==============================] - 19s 764ms/step - loss: 3.6283 - mae: 0.0747 - val_loss: 3.6269 - val_mae: 0.0756
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 3.5486 - mae: 0.0738
# Epoch 16: val_loss improved from 3.62384 to 3.60108, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 765ms/step - loss: 3.5486 - mae: 0.0738 - val_loss: 3.6011 - val_mae: 0.0754
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 3.5203 - mae: 0.0735
# Epoch 17: val_loss improved from 3.60108 to 3.55879, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 3.5203 - mae: 0.0735 - val_loss: 3.5588 - val_mae: 0.0747
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 3.5001 - mae: 0.0732
# Epoch 18: val_loss did not improve from 3.55879
# 25/25 [==============================] - 19s 760ms/step - loss: 3.5001 - mae: 0.0732 - val_loss: 3.5666 - val_mae: 0.0743
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 3.4849 - mae: 0.0731
# Epoch 19: val_loss improved from 3.55879 to 3.47565, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 762ms/step - loss: 3.4849 - mae: 0.0731 - val_loss: 3.4757 - val_mae: 0.0736
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 3.4962 - mae: 0.0732
# Epoch 20: val_loss did not improve from 3.47565
# 25/25 [==============================] - 19s 762ms/step - loss: 3.4962 - mae: 0.0732 - val_loss: 3.5333 - val_mae: 0.0743
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 3.4170 - mae: 0.0724
# Epoch 21: val_loss improved from 3.47565 to 3.47195, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 3.4170 - mae: 0.0724 - val_loss: 3.4719 - val_mae: 0.0734
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 3.4242 - mae: 0.0724
# Epoch 22: val_loss improved from 3.47195 to 3.39947, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 772ms/step - loss: 3.4242 - mae: 0.0724 - val_loss: 3.3995 - val_mae: 0.0728
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 3.3951 - mae: 0.0721
# Epoch 23: val_loss did not improve from 3.39947
# 25/25 [==============================] - 19s 764ms/step - loss: 3.3951 - mae: 0.0721 - val_loss: 3.5348 - val_mae: 0.0748
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 3.3503 - mae: 0.0717
# Epoch 24: val_loss improved from 3.39947 to 3.34621, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 764ms/step - loss: 3.3503 - mae: 0.0717 - val_loss: 3.3462 - val_mae: 0.0722
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 3.3211 - mae: 0.0713
# Epoch 25: val_loss improved from 3.34621 to 3.33835, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 762ms/step - loss: 3.3211 - mae: 0.0713 - val_loss: 3.3384 - val_mae: 0.0722
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2947 - mae: 0.0710
# Epoch 26: val_loss did not improve from 3.33835
# 25/25 [==============================] - 19s 759ms/step - loss: 3.2947 - mae: 0.0710 - val_loss: 3.3559 - val_mae: 0.0722
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2933 - mae: 0.0710
# Epoch 27: val_loss improved from 3.33835 to 3.33484, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 768ms/step - loss: 3.2933 - mae: 0.0710 - val_loss: 3.3348 - val_mae: 0.0720
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2909 - mae: 0.0710
# Epoch 28: val_loss improved from 3.33484 to 3.27013, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 767ms/step - loss: 3.2909 - mae: 0.0710 - val_loss: 3.2701 - val_mae: 0.0714
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2628 - mae: 0.0707
# Epoch 29: val_loss did not improve from 3.27013
# 25/25 [==============================] - 19s 763ms/step - loss: 3.2628 - mae: 0.0707 - val_loss: 3.2931 - val_mae: 0.0717
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2168 - mae: 0.0702
# Epoch 30: val_loss improved from 3.27013 to 3.22968, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 765ms/step - loss: 3.2168 - mae: 0.0702 - val_loss: 3.2297 - val_mae: 0.0709
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 3.2142 - mae: 0.0702
# Epoch 31: val_loss did not improve from 3.22968
# 25/25 [==============================] - 19s 762ms/step - loss: 3.2142 - mae: 0.0702 - val_loss: 3.2328 - val_mae: 0.0709
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1748 - mae: 0.0697
# Epoch 32: val_loss improved from 3.22968 to 3.19692, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 762ms/step - loss: 3.1748 - mae: 0.0697 - val_loss: 3.1969 - val_mae: 0.0705
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1978 - mae: 0.0699
# Epoch 33: val_loss did not improve from 3.19692
# 25/25 [==============================] - 19s 773ms/step - loss: 3.1978 - mae: 0.0699 - val_loss: 3.2145 - val_mae: 0.0707
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1622 - mae: 0.0695
# Epoch 34: val_loss did not improve from 3.19692
# 25/25 [==============================] - 19s 762ms/step - loss: 3.1622 - mae: 0.0695 - val_loss: 3.3683 - val_mae: 0.0726
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1525 - mae: 0.0694
# Epoch 35: val_loss improved from 3.19692 to 3.18537, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 3.1525 - mae: 0.0694 - val_loss: 3.1854 - val_mae: 0.0703
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1440 - mae: 0.0694
# Epoch 36: val_loss did not improve from 3.18537
# 25/25 [==============================] - 19s 760ms/step - loss: 3.1440 - mae: 0.0694 - val_loss: 3.2173 - val_mae: 0.0707
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1172 - mae: 0.0691
# Epoch 37: val_loss did not improve from 3.18537
# 25/25 [==============================] - 19s 759ms/step - loss: 3.1172 - mae: 0.0691 - val_loss: 3.2419 - val_mae: 0.0708
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0967 - mae: 0.0688
# Epoch 38: val_loss did not improve from 3.18537
# 25/25 [==============================] - 19s 765ms/step - loss: 3.0967 - mae: 0.0688 - val_loss: 3.2341 - val_mae: 0.0710
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1026 - mae: 0.0689
# Epoch 39: val_loss improved from 3.18537 to 3.15690, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 768ms/step - loss: 3.1026 - mae: 0.0689 - val_loss: 3.1569 - val_mae: 0.0699
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0955 - mae: 0.0688
# Epoch 40: val_loss did not improve from 3.15690
# 25/25 [==============================] - 19s 760ms/step - loss: 3.0955 - mae: 0.0688 - val_loss: 3.1574 - val_mae: 0.0698
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0980 - mae: 0.0688
# Epoch 41: val_loss did not improve from 3.15690
# 25/25 [==============================] - 19s 761ms/step - loss: 3.0980 - mae: 0.0688 - val_loss: 3.2972 - val_mae: 0.0718
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 3.1426 - mae: 0.0692
# Epoch 42: val_loss did not improve from 3.15690
# 25/25 [==============================] - 19s 762ms/step - loss: 3.1426 - mae: 0.0692 - val_loss: 3.1662 - val_mae: 0.0702
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0859 - mae: 0.0688
# Epoch 43: val_loss did not improve from 3.15690
# 25/25 [==============================] - 19s 761ms/step - loss: 3.0859 - mae: 0.0688 - val_loss: 3.1789 - val_mae: 0.0701
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0529 - mae: 0.0684
# Epoch 44: val_loss improved from 3.15690 to 3.07972, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 768ms/step - loss: 3.0529 - mae: 0.0684 - val_loss: 3.0797 - val_mae: 0.0691
# Epoch 45/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0320 - mae: 0.0681
# Epoch 45: val_loss did not improve from 3.07972
# 25/25 [==============================] - 19s 762ms/step - loss: 3.0320 - mae: 0.0681 - val_loss: 3.1011 - val_mae: 0.0692
# Epoch 46/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0598 - mae: 0.0684
# Epoch 46: val_loss did not improve from 3.07972
# 25/25 [==============================] - 19s 762ms/step - loss: 3.0598 - mae: 0.0684 - val_loss: 3.1528 - val_mae: 0.0700
# Epoch 47/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0461 - mae: 0.0683
# Epoch 47: val_loss did not improve from 3.07972
# 25/25 [==============================] - 19s 762ms/step - loss: 3.0461 - mae: 0.0683 - val_loss: 3.2907 - val_mae: 0.0714
# Epoch 48/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0100 - mae: 0.0678
# Epoch 48: val_loss did not improve from 3.07972
# 25/25 [==============================] - 19s 766ms/step - loss: 3.0100 - mae: 0.0678 - val_loss: 3.1281 - val_mae: 0.0695
# Epoch 49/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0203 - mae: 0.0680
# Epoch 49: val_loss improved from 3.07972 to 3.06635, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 767ms/step - loss: 3.0203 - mae: 0.0680 - val_loss: 3.0663 - val_mae: 0.0688
# Epoch 50/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0046 - mae: 0.0677
# Epoch 50: val_loss did not improve from 3.06635
# 25/25 [==============================] - 19s 760ms/step - loss: 3.0046 - mae: 0.0677 - val_loss: 3.0724 - val_mae: 0.0690
# Epoch 51/100
# 25/25 [==============================] - ETA: 0s - loss: 3.0013 - mae: 0.0678
# Epoch 51: val_loss did not improve from 3.06635
# 25/25 [==============================] - 19s 762ms/step - loss: 3.0013 - mae: 0.0678 - val_loss: 3.0756 - val_mae: 0.0687
# Epoch 52/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9962 - mae: 0.0676
# Epoch 52: val_loss improved from 3.06635 to 3.05089, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 773ms/step - loss: 2.9962 - mae: 0.0676 - val_loss: 3.0509 - val_mae: 0.0687
# Epoch 53/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9705 - mae: 0.0674
# Epoch 53: val_loss did not improve from 3.05089
# 25/25 [==============================] - 19s 760ms/step - loss: 2.9705 - mae: 0.0674 - val_loss: 3.1438 - val_mae: 0.0700
# Epoch 54/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9818 - mae: 0.0675
# Epoch 54: val_loss improved from 3.05089 to 3.02098, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 771ms/step - loss: 2.9818 - mae: 0.0675 - val_loss: 3.0210 - val_mae: 0.0685
# Epoch 55/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9831 - mae: 0.0675
# Epoch 55: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 764ms/step - loss: 2.9831 - mae: 0.0675 - val_loss: 3.0803 - val_mae: 0.0690
# Epoch 56/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9944 - mae: 0.0676
# Epoch 56: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 764ms/step - loss: 2.9944 - mae: 0.0676 - val_loss: 3.1714 - val_mae: 0.0702
# Epoch 57/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9592 - mae: 0.0673
# Epoch 57: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 760ms/step - loss: 2.9592 - mae: 0.0673 - val_loss: 3.1974 - val_mae: 0.0703
# Epoch 58/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9535 - mae: 0.0672
# Epoch 58: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 763ms/step - loss: 2.9535 - mae: 0.0672 - val_loss: 3.0520 - val_mae: 0.0686
# Epoch 59/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9828 - mae: 0.0675
# Epoch 59: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 763ms/step - loss: 2.9828 - mae: 0.0675 - val_loss: 3.0462 - val_mae: 0.0686
# Epoch 60/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9495 - mae: 0.0671
# Epoch 60: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 760ms/step - loss: 2.9495 - mae: 0.0671 - val_loss: 3.1525 - val_mae: 0.0703
# Epoch 61/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9432 - mae: 0.0671
# Epoch 61: val_loss did not improve from 3.02098
# 25/25 [==============================] - 19s 759ms/step - loss: 2.9432 - mae: 0.0671 - val_loss: 3.0545 - val_mae: 0.0686
# Epoch 62/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9338 - mae: 0.0669
# Epoch 62: val_loss improved from 3.02098 to 2.96891, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 762ms/step - loss: 2.9338 - mae: 0.0669 - val_loss: 2.9689 - val_mae: 0.0677
# Epoch 63/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9309 - mae: 0.0669
# Epoch 63: val_loss did not improve from 2.96891
# 25/25 [==============================] - 19s 763ms/step - loss: 2.9309 - mae: 0.0669 - val_loss: 3.0036 - val_mae: 0.0680
# Epoch 64/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9201 - mae: 0.0668
# Epoch 64: val_loss did not improve from 2.96891
# 25/25 [==============================] - 19s 761ms/step - loss: 2.9201 - mae: 0.0668 - val_loss: 2.9767 - val_mae: 0.0678
# Epoch 65/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9533 - mae: 0.0671
# Epoch 65: val_loss did not improve from 2.96891
# 25/25 [==============================] - 19s 761ms/step - loss: 2.9533 - mae: 0.0671 - val_loss: 3.0611 - val_mae: 0.0689
# Epoch 66/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9353 - mae: 0.0669
# Epoch 66: val_loss improved from 2.96891 to 2.96778, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 2.9353 - mae: 0.0669 - val_loss: 2.9678 - val_mae: 0.0677
# Epoch 67/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9359 - mae: 0.0669
# Epoch 67: val_loss did not improve from 2.96778
# 25/25 [==============================] - 19s 760ms/step - loss: 2.9359 - mae: 0.0669 - val_loss: 3.0075 - val_mae: 0.0682
# Epoch 68/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9268 - mae: 0.0669
# Epoch 68: val_loss did not improve from 2.96778
# 25/25 [==============================] - 19s 759ms/step - loss: 2.9268 - mae: 0.0669 - val_loss: 3.0020 - val_mae: 0.0682
# Epoch 69/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9121 - mae: 0.0666
# Epoch 69: val_loss did not improve from 2.96778
# 25/25 [==============================] - 19s 761ms/step - loss: 2.9121 - mae: 0.0666 - val_loss: 2.9813 - val_mae: 0.0679
# Epoch 70/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9330 - mae: 0.0669
# Epoch 70: val_loss did not improve from 2.96778
# 25/25 [==============================] - 19s 761ms/step - loss: 2.9330 - mae: 0.0669 - val_loss: 3.0348 - val_mae: 0.0686
# Epoch 71/100
# 25/25 [==============================] - ETA: 0s - loss: 2.9206 - mae: 0.0667
# Epoch 71: val_loss did not improve from 2.96778
# 25/25 [==============================] - 19s 766ms/step - loss: 2.9206 - mae: 0.0667 - val_loss: 2.9723 - val_mae: 0.0676
# Epoch 72/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8814 - mae: 0.0663
# Epoch 72: val_loss improved from 2.96778 to 2.96619, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 2.8814 - mae: 0.0663 - val_loss: 2.9662 - val_mae: 0.0677
# Epoch 73/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8761 - mae: 0.0662
# Epoch 73: val_loss did not improve from 2.96619
# 25/25 [==============================] - 19s 763ms/step - loss: 2.8761 - mae: 0.0662 - val_loss: 3.0310 - val_mae: 0.0687
# Epoch 74/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8669 - mae: 0.0662
# Epoch 74: val_loss did not improve from 2.96619
# 25/25 [==============================] - 19s 761ms/step - loss: 2.8669 - mae: 0.0662 - val_loss: 3.1791 - val_mae: 0.0704
# Epoch 75/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8638 - mae: 0.0661
# Epoch 75: val_loss improved from 2.96619 to 2.93082, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 2.8638 - mae: 0.0661 - val_loss: 2.9308 - val_mae: 0.0673
# Epoch 76/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8470 - mae: 0.0659
# Epoch 76: val_loss did not improve from 2.93082
# 25/25 [==============================] - 19s 760ms/step - loss: 2.8470 - mae: 0.0659 - val_loss: 3.0337 - val_mae: 0.0688
# Epoch 77/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8461 - mae: 0.0659
# Epoch 77: val_loss did not improve from 2.93082
# 25/25 [==============================] - 19s 763ms/step - loss: 2.8461 - mae: 0.0659 - val_loss: 2.9662 - val_mae: 0.0678
# Epoch 78/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8517 - mae: 0.0660
# Epoch 78: val_loss improved from 2.93082 to 2.91423, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 763ms/step - loss: 2.8517 - mae: 0.0660 - val_loss: 2.9142 - val_mae: 0.0671
# Epoch 79/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8384 - mae: 0.0658
# Epoch 79: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 757ms/step - loss: 2.8384 - mae: 0.0658 - val_loss: 2.9648 - val_mae: 0.0676
# Epoch 80/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8311 - mae: 0.0657
# Epoch 80: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 759ms/step - loss: 2.8311 - mae: 0.0657 - val_loss: 3.0312 - val_mae: 0.0683
# Epoch 81/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8341 - mae: 0.0658
# Epoch 81: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 762ms/step - loss: 2.8341 - mae: 0.0658 - val_loss: 2.9285 - val_mae: 0.0673
# Epoch 82/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8362 - mae: 0.0658
# Epoch 82: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 760ms/step - loss: 2.8362 - mae: 0.0658 - val_loss: 2.9324 - val_mae: 0.0673
# Epoch 83/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8451 - mae: 0.0659
# Epoch 83: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 760ms/step - loss: 2.8451 - mae: 0.0659 - val_loss: 2.9661 - val_mae: 0.0679
# Epoch 84/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8285 - mae: 0.0657
# Epoch 84: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 758ms/step - loss: 2.8285 - mae: 0.0657 - val_loss: 2.9864 - val_mae: 0.0681
# Epoch 85/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8266 - mae: 0.0657
# Epoch 85: val_loss did not improve from 2.91423
# 25/25 [==============================] - 19s 758ms/step - loss: 2.8266 - mae: 0.0657 - val_loss: 2.9403 - val_mae: 0.0674
# Epoch 86/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8087 - mae: 0.0655
# Epoch 86: val_loss improved from 2.91423 to 2.90844, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 766ms/step - loss: 2.8087 - mae: 0.0655 - val_loss: 2.9084 - val_mae: 0.0670
# Epoch 87/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8022 - mae: 0.0654
# Epoch 87: val_loss did not improve from 2.90844
# 25/25 [==============================] - 19s 765ms/step - loss: 2.8022 - mae: 0.0654 - val_loss: 2.9878 - val_mae: 0.0681
# Epoch 88/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8228 - mae: 0.0656
# Epoch 88: val_loss improved from 2.90844 to 2.89785, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 768ms/step - loss: 2.8228 - mae: 0.0656 - val_loss: 2.8978 - val_mae: 0.0668
# Epoch 89/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8140 - mae: 0.0655
# Epoch 89: val_loss did not improve from 2.89785
# 25/25 [==============================] - 19s 761ms/step - loss: 2.8140 - mae: 0.0655 - val_loss: 2.9320 - val_mae: 0.0673
# Epoch 90/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8120 - mae: 0.0655
# Epoch 90: val_loss improved from 2.89785 to 2.89291, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 768ms/step - loss: 2.8120 - mae: 0.0655 - val_loss: 2.8929 - val_mae: 0.0669
# Epoch 91/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8029 - mae: 0.0654
# Epoch 91: val_loss did not improve from 2.89291
# 25/25 [==============================] - 19s 765ms/step - loss: 2.8029 - mae: 0.0654 - val_loss: 2.9783 - val_mae: 0.0679
# Epoch 92/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7964 - mae: 0.0653
# Epoch 92: val_loss did not improve from 2.89291
# 25/25 [==============================] - 19s 760ms/step - loss: 2.7964 - mae: 0.0653 - val_loss: 2.9454 - val_mae: 0.0675
# Epoch 93/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7847 - mae: 0.0652
# Epoch 93: val_loss improved from 2.89291 to 2.86310, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 763ms/step - loss: 2.7847 - mae: 0.0652 - val_loss: 2.8631 - val_mae: 0.0663
# Epoch 94/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7898 - mae: 0.0652
# Epoch 94: val_loss did not improve from 2.86310
# 25/25 [==============================] - 19s 762ms/step - loss: 2.7898 - mae: 0.0652 - val_loss: 2.9064 - val_mae: 0.0668
# Epoch 95/100
# 25/25 [==============================] - ETA: 0s - loss: 2.8196 - mae: 0.0656
# Epoch 95: val_loss did not improve from 2.86310
# 25/25 [==============================] - 19s 762ms/step - loss: 2.8196 - mae: 0.0656 - val_loss: 2.8829 - val_mae: 0.0665
# Epoch 96/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7889 - mae: 0.0652
# Epoch 96: val_loss improved from 2.86310 to 2.86133, saving model to rna_stereo_CVN_REC_weigths
# 25/25 [==============================] - 19s 767ms/step - loss: 2.7889 - mae: 0.0652 - val_loss: 2.8613 - val_mae: 0.0664
# Epoch 97/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7978 - mae: 0.0653
# Epoch 97: val_loss did not improve from 2.86133
# 25/25 [==============================] - 19s 754ms/step - loss: 2.7978 - mae: 0.0653 - val_loss: 2.8890 - val_mae: 0.0665
# Epoch 98/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7921 - mae: 0.0652
# Epoch 98: val_loss did not improve from 2.86133
# 25/25 [==============================] - 19s 759ms/step - loss: 2.7921 - mae: 0.0652 - val_loss: 2.9329 - val_mae: 0.0673
# Epoch 99/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7878 - mae: 0.0652
# Epoch 99: val_loss did not improve from 2.86133
# 25/25 [==============================] - 19s 764ms/step - loss: 2.7878 - mae: 0.0652 - val_loss: 2.9152 - val_mae: 0.0671
# Epoch 100/100
# 25/25 [==============================] - ETA: 0s - loss: 2.7854 - mae: 0.0652
# Epoch 100: val_loss did not improve from 2.86133
# 25/25 [==============================] - 19s 763ms/step - loss: 2.7854 - mae: 0.0652 - val_loss: 2.8637 - val_mae: 0.0663

# %% [markdown]
# ### 4.3 Salva a rede treinada
#
# Após o término do processo de treinamento a rede e os seus parâmetros são salvos. Pode-se carregar os parâmetros da rede usando.

# %%
# Restore the weights
rna_stereo.load_weights('rna_stereo_CVN_REC_weigths')#'my_checkpoint_classic')

# %% [markdown]
# ### 4.4 Resultados
#
# As células abaixo apresentam os gráficos do processo de treinamento e a avaliação da rede pelo cálculo da função de custo e métrica para os dados de treinamento e validação.

# %%
# Obtém dicionário com os resultados do treinamento
results_dict = results.history

# Salva custos, métricas e epocas em vetores 
custo = results_dict['loss']
#rec_mae = results_dict['rec_img_mae']
#disp_mae = results_dict['disp_mae']
val_custo = results_dict['val_loss']
#val_rec_mae = results_dict['val_rec_img_mae']
#val_disp_mae = results_dict['val_disp_mae']
val_mae = results_dict['val_mae']

# Cria vetor de épocas
epocas = range(1, len(custo) + 1)

# Gráfico dos valores de custo
plt.plot(epocas, custo, 'b', label='Custo - treinamento')
plt.plot(epocas, val_custo, 'r', label='Custo - validação')
plt.title('Valor da função de custo – treinamento e validação')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
plt.show()

# Gráfico dos valores da métrica
#plt.plot(epocas, rec_mae, 'b', label='MAE - treinamento')
plt.plot(epocas, val_mae, 'r', label='MAE - validação')
plt.title('Valor da métrica de reconstrução – treinamento e validação')
plt.xlabel('Épocas')
plt.ylabel('REC_MAE')
plt.legend()
plt.show()

# Gráfico dos valores da métrica

# %%
results_dict.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
custo_metrica_train = rna_stereo.evaluate(batch_generator(train_left_img_paths, train_right_img_paths, img_size, m_train, batchsize=batch_size), steps=train_steps)
custo_metrica_val = rna_stereo.evaluate(batch_generator(val_left_img_paths, val_right_img_paths, img_size, m_val, batchsize=batch_size), steps=val_steps)
# Out:
# 25/25 [==============================] - 10s 419ms/step - loss: 2.7945 - mae: 0.0653
# 6/6 [==============================] - 2s 409ms/step - loss: 2.8613 - mae: 0.0664

# %% [markdown]
# ## 5. Previsões da rede
#
# Vamos verificar se a rede desenvolvida é eficaz em realizar segmentação de imagens. Para isso vamos calcular a sua previsão para alguns exemplos  do conjunto de validação e verificar a qualidade o mapa de disparidade e compará-lo com o mapa de dispatidade real.

# %%
# Instancia o gerador de dados de validação
datagen = batch_generator(val_left_img_paths, val_right_img_paths, img_size, m_val, batchsize=8)

# Gera lote de exemplos de valiação
[left_img_batch, right_img_batch], [out_img_batch] = next(datagen) 

# Calcula previsão da rede para o lote de validação gerado
img_prev_batch = rna_stereo.predict([left_img_batch, right_img_batch])

# Seleciona exemplo para análise
index = 6
left_img = left_img_batch[index]
right_img = right_img_batch[index]
img_prev = img_prev_batch[index]
#disp_prev = disp_prev_batch[index]

# Retira eixos dos exemplos
left_img = np.squeeze(left_img)
right_img = np.squeeze(right_img)
#disp_prev = np.squeeze(disp_prev)

# Mostra resultados do exemplos slecionado
f, pos = plt.subplots(2, 1, figsize=(12, 12))
pos[0].imshow(right_img)
pos[1].imshow(img_prev)
#pos[1,1].imshow(disp_prev, cmap='gray')
plt.show()

# %%
# Calcula erro de previsão disparidade


# Calcula erro de previsão de recosntrução
img_batch = np.squeeze(img_prev_batch)
erro = np.mean(100*np.mean(np.abs(right_img_batch - img_batch)))/np.mean(right_img_batch)
print('Erro absoluto médio percentual recosntrução (%):', erro)
# Out:
# Erro absoluto médio percentual recosntrução (%): 11.678042259203337

# %%
# Seleciona exemplo para análise
index = 1
left_img = left_img_batch[index]
right_img = right_img_batch[index]
#disp_prev = disp_prev_batch[index]
img_prev = img_prev_batch[index]

# Retira eixos dos exemplos
left_img = np.squeeze(left_img)
right_img = np.squeeze(right_img)
#disp_prev = np.squeeze(disp_prev)
img_prev = np.squeeze(img_prev)

# Mostra resultados do exemplos slecionado
f, pos = plt.subplots(2, 2, figsize=(12, 12))
pos[0,0].imshow(right_img)
pos[0,1].imshow(img_prev)
#pos[1,1].imshow(disp_prev, cmap='gray')
plt.show()

# %%
# Calcula erro de previsão 


# Apresenta alguns valores das imagens segmentadas
print(disp_prev[index,:].astype(int))

# %% [markdown]
# ### Teste com imagens diferentes
#
# Tem que carregar a imagem.

# %%
from keras.preprocessing.image import load_img, img_to_array

left_imagem = load_img('/content/left_1661700892724891100.png')
right_imagem = load_img('/content/right_1661700892724891100.png')

img_left = img_to_array(left_imagem)
img_right = img_to_array(right_imagem)

print(img_left.shape, img_right.shape)
print(np.max(img_left), np.max(img_right))
# Out:
# (360, 640, 3) (360, 640, 3)
# 255.0 255.0

# %%
img_left = tf.image.resize(img_left, img_size)/255.
img_right = tf.image.resize(img_right, img_size)/255.

img_left = np.expand_dims(img_left, axis=0)
img_right = np.expand_dims(img_right, axis=0)

print(np.max(img_left), np.max(img_right))
# Out:
# 1.0 1.0

# %%
# Mostra resultados do exemplos selecionado
img_prev = rna_stereo.predict([img_left, img_right])

f, pos = plt.subplots(2, 2, figsize=(12, 12))
pos[0,0].imshow(img_right[0])
pos[0,1].imshow(img_prev[0])
plt.show()

# %%
# Calcula erro de previsão 


# Apresenta alguns valores das imagens segmentadas
print(disp_prev[128,:].astype(int))

# %%
# Calculo do erro de reconstrução
erro_rec = np.mean(100*np.abs(img_prev - img_right))/np.mean(img_right)
print('Erro absoluto médio percentual (%):', erro_rec)
# Out:
# Erro absoluto médio percentual (%): 15.124584
